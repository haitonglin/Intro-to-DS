# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Haitong Lin"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# Problem 1 of Assignment 14, STATS102 Fall2019 Session 2, Duke Kunshan University, Due at Nov 21th 12：00pm beijing time
# ![](dku.jpg)
# For this problem set, we'll be using the Jupyter notebook and nbgrader:
#
# ![](jupyter.png)

# %% [markdown]
# # Problem 1
#
# Loading <b>Data_1.npy</b> and <b>Data_2.npy</b>, draw histograms with legends, title. (bins=100)
#
# ![](assignment14_1.png)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

def myplot():
    data_1 = np.load('Data_1.npy').reshape(10000,1)
    # YOUR CODE HERE
    data_2=np.load('Data_2.npy').reshape(10000,1)
    
    plt.hist(data_1,bins=100,color='C8',alpha=0.6);
    plt.hist(data_2,bins=100,color='C2',alpha=0.6);
    plt.xlim(-3,5)
    
    plt.title('Sample distribution')
    plt.legend(['Data 1','Data 2'])

# %%
myplot()

# %% [markdown]
# # Problem 2
#
# Draw the Maurer rose curve (https://en.wikipedia.org/wiki/Maurer_rose) when $n=6, d=71$.
#
# Hint: $\frac{\pi}{180}\approx0.0174533$, polar coordinate system to Cartesian coordinate system (https://en.wikipedia.org/wiki/Polar_coordinate_system)
#
# ![](assignment14.png)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import math

def myplot():
    n = 6
    d = 71
    # YOUR CODE HERE
    X=[]
    Y=[]
    
    for a in range(361):
        
        k=a*d*math.pi/180
        r=math.sin(n*k)
        x=r*math.cos(k)
        y=r*math.sin(k)
        
        X.append(x)
        Y.append(y)
        
    ax=plt.axes()
    ax.plot(X,Y)
    ax.set(xlim=(-1.5,1.5),ylim=(-1.00,1.00),title='Maurer rose')

# %%
myplot()
